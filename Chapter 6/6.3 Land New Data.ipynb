-- %%
%run ../Includes/School-Setup

-- %%
%python
display(dbutils.fs.ls(f"{dataset_school}/courses-cdc"))

-- %%
%python
load_new_json_data()

-- %%
select * from json.`dbfs:/mnt/DE-Associate-Book/datasets/school/courses-cdc`
