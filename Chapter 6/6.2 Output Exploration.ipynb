-- %% [markdown]
-- # Examining DLT pipelines

-- %%
%fs ls "dbfs:/mnt/DEA-Book/dlt"

-- %%
%fs ls "dbfs:/mnt/DEA-Book/dlt/system/events"

-- %%
SELECT * FROM delta.`dbfs:/mnt/DEA-Book/dlt/system/events`

-- %%
%fs ls dbfs:/mnt/DEA-Book/dlt/schemas/school_dlt_db/tables

-- %%
SELECT * FROM managed_catalog.school_dlt_db.uk_daily_student_courses
