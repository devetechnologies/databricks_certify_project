-- %%
--drop table managed_catalog.school_dlt_db.enrollments_cleaned;
--drop table managed_catalog.school_dlt_db.students_dlt;
--drop table managed_catalog.school_dlt_db.uk_daily_student_courses;
--drop table managed_catalog.school_dlt_db.enrollments_raw;

-- %%
%fs ls "dbfs:/mnt/DEA-Book/checkpoints"
