# %%
# %run ../Includes/School-Setup

# %%
# %sql
select * from enrollments;

# %%
# %sql
select  
enroll_id,
courses,
filter(
  courses,
  course -> course.discount_percent >= ) as high_discounted_courses
from enrollments

# %%
# %sql
select enroll_id,
high_discounted_courses
from(
  select 
  enroll_id,
  courses,
  filter(
    courses,
    course -> course.discount_percent >= 60 ) as high_discounted_courses
    from enrollments
)
where size(high_discounted_courses)> 0
